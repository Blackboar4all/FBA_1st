# %% [markdown]
# # Buy &Hold Strategy

# %%
# CAGR-연복리수익률
# MDD-최대손실가능수익률=(최고가-최저가)/최고가
# Sharpe Ratio(펀드수익률-벤치마크수익률)/(해당펀드수익률표준편차)

## Performance Measure
# CAGR : 연복리수익률, 일별 data를 사용 한 경우 -> 전체연도를 계산하는 경우 전체 data 기간을 252영업일로 나눈 역수를 제곱(승)을 한 후 -1 을 한다.
# MDD(Max-DrawDown) : 최대손실가능수익률
# VOL : 연 주가수익률 표준편차 = 일변 주가수익률 X  252일 제곱근 (영업일수 고려, IID 가정 )
# Sharpe : 총위험 1단위당 초과수익률 ( 위험을 고려한 초과수익)

# %%
# !pip install yfinance
import numpy as np
import pandas as pd
import warnings
import os
import yfinance as yf
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.67-py2.py3-none-any.whl (25 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 17.4 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.10.8)
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.4 yfinance-0.1.67

# %%
df = yf.download('028050.KS', start = '2017-01-01', end='2019-12-31')  #01. 삼성엔지니어링(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('01.삼성엔지니어링(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 01.삼성엔지니어링(주)
# CAGR :  23.33 %
# Sharpe :  0.75
# VOL :  37.32 %
# MDD :  28.22 %

# %%
df = yf.download('071970.KS', start = '2017-01-01', end='2019-12-31') #02.STX중공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('02. STX중공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 02. STX중공업(주)
# CAGR :  -75.8 %
# Sharpe :  -1.01
# VOL :  89.51 %
# MDD :  99.63 %

# %%
df = yf.download('071950.KS', start = '2017-01-01', end='2019-12-31') #03. (주)코아스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('03. (주)코아스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 03. (주)코아스
# CAGR :  -8.42 %
# Sharpe :  0.18
# VOL :  64.83 %
# MDD :  62.8 %

# %%
df = yf.download('306200.KS', start = '2017-01-01', end='2019-12-31') #04. (주)세아제강
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('04. (주)세아제강')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 04. (주)세아제강
# CAGR :  -4.21 %
# Sharpe :  0.02
# VOL :  31.19 %
# MDD :  22.22 %

# %%
df = yf.download('007570.KS', start = '2017-01-01', end='2019-12-31') #05. 일양약품(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('05.일양약품(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 05.일양약품(주)
# CAGR :  -18.06 %
# Sharpe :  -0.48
# VOL :  31.38 %
# MDD :  58.31 %

# %%
df = yf.download('003070.KS', start = '2017-01-01', end='2019-12-31') #06. 코오롱글로벌(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('06. 코오롱글로벌(주)') 
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 06. 코오롱글로벌(주)
# CAGR :  -2.64 %
# Sharpe :  0.14
# VOL :  42.84 %
# MDD :  60.96 %

# %%
df = yf.download('012280.KS', start = '2017-01-01', end='2019-12-31') #07.영화금속(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('07. 영화금속(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 07. 영화금속(주)
# CAGR :  -4.79 %
# Sharpe :  0.02
# VOL :  33.18 %
# MDD :  45.69 %

# %%
df = yf.download('004920.KS', start = '2017-01-01', end='2019-12-31') #08. (주)씨아이테크
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('08. (주)씨아이테크')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 08. (주)씨아이테크
# CAGR :  -18.87 %
# Sharpe :  -0.3
# VOL :  41.6 %
# MDD :  61.31 %

# %%
df = yf.download('027970.KS', start = '2017-01-01', end='2019-12-31') # 09.세하(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('09. 세하(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 09. 세하(주)
# CAGR :  4.36 %
# Sharpe :  0.3
# VOL :  40.16 %
# MDD :  56.73 %

# %%
df = yf.download('010820.KS', start = '2017-01-01', end='2019-12-31') #10. 퍼스텍(주) 
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('10. 퍼스텍(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 10. 퍼스텍(주)
# CAGR :  -18.54 %
# Sharpe :  -0.09
# VOL :  56.19 %
# MDD :  78.88 %

# %%
df = yf.download('008970.KS', start = '2017-01-01', end='2019-12-31') #11. 동양철관(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('11. 동양철관(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 11. 동양철관(주)
# CAGR :  -2.78 %
# Sharpe :  0.31
# VOL :  69.88 %
# MDD :  72.94 %

# %%
df = yf.download('073240.KS', start = '2017-01-01', end='2019-12-31') #12. 금호타이어(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('12. 금호타이어(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 12. 금호타이어(주)
# CAGR :  -21.67 %
# Sharpe :  -0.11
# VOL :  59.98 %
# MDD :  63.41 %

# %%
df = yf.download('015590.KS', start = '2017-01-01', end='2019-12-31') #13.(주)큐로
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('13. (주)큐로 ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 13. (주)큐로
# CAGR :  3.67 %
# Sharpe :  0.34
# VOL :  56.29 %
# MDD :  65.33 %

# %%
df = yf.download('008040.KS', start = '2017-01-01', end='2019-12-31') #14.사조동아원(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('14. 사조동아원(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 14. 사조동아원(주)
# CAGR :  -15.44 %
# Sharpe :  -0.27
# VOL :  37.43 %
# MDD :  45.03 %

# %%
df = yf.download('004140.KS', start = '2017-01-01', end='2019-12-31') #15. (주)동방
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('15. (주)동방')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 15. (주)동방
# CAGR :  -9.03 %
# Sharpe :  0.06
# VOL :  51.35 %
# MDD :  54.51 %

# %%
df = yf.download('000140.KS', start = '2017-01-01', end='2019-12-31') #16. 하이트진로홀딩스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('16. 하이트진로홀딩스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 16. 하이트진로홀딩스(주)
# CAGR :  4.76 %
# Sharpe :  0.3
# VOL :  32.77 %
# MDD :  48.16 %

# %%
df = yf.download('004710.KS', start = '2017-01-01', end='2019-12-31') #17. 한솔테크닉스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('17. 한솔테크닉스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 17. 한솔테크닉스(주)
# CAGR :  -14.92 %
# Sharpe :  -0.18
# VOL :  41.76 %
# MDD :  70.31 %

# %%
df = yf.download('002410.KS', start = '2017-01-01', end='2019-12-31') #18. 범양건영(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('18. 범양건영(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 18. 범양건영(주)
# CAGR :  7.38 %
# Sharpe :  0.39
# VOL :  55.96 %
# MDD :  63.7 %

# %%
df = yf.download('298000.KS', start = '2017-01-01', end='2019-12-31') #19.효성화학(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('19.효성화학(주))')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 19.효성화학(주))
# CAGR :  0.55 %
# Sharpe :  0.23
# VOL :  44.93 %
# MDD :  41.52 %

# %%
df = yf.download('009200.KS', start = '2017-01-01', end='2019-12-31') #20.무림페이퍼(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('20.무림페이퍼(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 20.무림페이퍼(주)
# CAGR :  -0.47 %
# Sharpe :  0.13
# VOL :  28.56 %
# MDD :  38.75 %

# %%
df = yf.download('298020.KS', start = '2017-01-01', end='2019-12-31') #21.효성티앤씨(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('21.효성티앤씨(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 21.효성티앤씨(주)
# CAGR :  -27.17 %
# Sharpe :  -0.81
# VOL :  32.48 %
# MDD :  44.34 %

# %%
df = yf.download('030720.KS', start = '2017-01-01', end='2019-12-31') #22.동원수산(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('22.동원수산(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 22.동원수산(주)
# CAGR :  1.68 %
# Sharpe :  0.26
# VOL :  47.19 %
# MDD :  44.66 %

# %%
df = yf.download('001230.KS', start = '2017-01-01', end='2019-12-31') #23.동국제강(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('23.동국제강(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 23.동국제강(주)
# CAGR :  -20.42 %
# Sharpe :  -0.35
# VOL :  41.34 %
# MDD :  63.15 %

# %%
df = yf.download('272550.KS', start = '2017-01-01', end='2019-12-31') #24.(주)삼양패키징
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('24.(주)삼양패키징')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 24.(주)삼양패키징
# CAGR :  -15.24 %
# Sharpe :  -0.43
# VOL :  28.84 %
# MDD :  38.46 %

# %%
df = yf.download('012030.KS', start = '2017-01-01', end='2019-12-31') #25.(주)디비아이엔씨
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('25.(주)디비아이엔씨')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 25.(주)디비아이엔씨
# CAGR :  6.01 %
# Sharpe :  0.34
# VOL :  37.1 %
# MDD :  37.93 %

# %%
df = yf.download('044450.KS', start = '2017-01-01', end='2019-12-31') #26.(주)케이에스에스해운
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('26.(주)케이에스에스해운')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 26.(주)케이에스에스해운
# CAGR :  1.62 %
# Sharpe :  0.18
# VOL :  20.9 %
# MDD :  39.08 %

# %%
df = yf.download('002990.KS', start = '2017-01-01', end='2019-12-31') #27. 금호산업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('27.금호산업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 27.금호산업(주)
# CAGR :  11.23 %
# Sharpe :  0.46
# VOL :  49.85 %
# MDD :  41.63 %

# %%
df = yf.download('294870.KS', start = '2017-01-01', end='2019-12-31') #28.에이치디씨현대산업개발(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('28.에이치디씨현대산업개발(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 28.에이치디씨현대산업개발(주)
# CAGR :  -50.06 %
# Sharpe :  -1.42
# VOL :  42.61 %
# MDD :  66.33 %

# %%
df = yf.download('204320.KS', start = '2017-01-01', end='2019-12-31') #29.(주)만도
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('29.(주)만도')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 29.(주)만도
# CAGR :  -10.15 %
# Sharpe :  -0.03
# VOL :  43.12 %
# MDD :  60.77 %

# %%
df = yf.download('120110.KS', start = '2017-01-01', end='2019-12-31') #31.코오롱인더스트리(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('31.코오롱인더스트리(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 31.코오롱인더스트리(주)
# CAGR :  -13.38 %
# Sharpe :  -0.29
# VOL :  32.01 %
# MDD :  57.74 %

# %%
df = yf.download('001780.KS', start = '2017-01-01', end='2019-12-31') #32.(주)알루코
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('32.(주)알루코')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 32.(주)알루코
# CAGR :  -19.58 %
# Sharpe :  -0.28
# VOL :  44.3 %
# MDD :  65.29 %

# %%
df = yf.download('005090.KS', start = '2017-01-01', end='2019-12-31') #33.에스지씨에너지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('33.에스지씨에너지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 33.에스지씨에너지(주)
# CAGR :  -22.23 %
# Sharpe :  -0.5
# VOL :  36.21 %
# MDD :  61.22 %

# %%
df = yf.download('002870.KS', start = '2017-01-01', end='2019-12-31') #34.신풍제지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('34.신풍제지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 34.신풍제지(주)
# CAGR :  20.63 %
# Sharpe :  0.64
# VOL :  43.63 %
# MDD :  47.28 %

# %%
df = yf.download('011070.KS', start = '2017-01-01', end='2019-12-31') #35.LG이노텍(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('35.LG이노텍(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 35.LG이노텍(주)
# CAGR :  18.79 %
# Sharpe :  0.62
# VOL :  42.45 %
# MDD :  55.7 %

# %%
df = yf.download('170900.KS', start = '2017-01-01', end='2019-12-31') #36.동아에스티(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('36.동아에스티(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 36.동아에스티(주)
# CAGR :  5.42 %
# Sharpe :  0.32
# VOL :  35.55 %
# MDD :  35.36 %

# %%
df = yf.download('163560.KS', start = '2017-01-01', end='2019-12-31') #37.동일고무벨트(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('37.동일고무벨트(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 37.동일고무벨트(주)
# CAGR :  -20.45 %
# Sharpe :  -0.97
# VOL :  21.21 %
# MDD :  55.43 %

# %%
df = yf.download('084680.KS', start = '2017-01-01', end='2019-12-31') #38.(주)이월드
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('38.(주)이월드')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 38.(주)이월드
# CAGR :  29.9 %
# Sharpe :  0.72
# VOL :  59.95 %
# MDD :  36.8 %

# %%
df = yf.download('003480.KS', start = '2017-01-01', end='2019-12-31') #39.(주)한진중공업홀딩스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('39.(주)한진중공업홀딩스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 39.(주)한진중공업홀딩스
# CAGR :  -20.88 %
# Sharpe :  -0.31
# VOL :  44.81 %
# MDD :  66.35 %

# %%
df = yf.download('001210.KS', start = '2017-01-01', end='2019-12-31') #40.금호전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('40.금호전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 40.금호전기(주)
# CAGR :  -23.93 %
# Sharpe :  -0.32
# VOL :  49.43 %
# MDD :  82.66 %

# %%
df = yf.download('010600.KS', start = '2017-01-01', end='2019-12-31') #41.웰바이오텍(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('41.웰바이오텍(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 41.웰바이오텍(주)
# CAGR :  2.48 %
# Sharpe :  0.42
# VOL :  80.12 %
# MDD :  80.49 %

# %%
df = yf.download('003580.KS', start = '2017-01-01', end='2019-12-31') #42.(주)넥스트사이언스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('42.(주)넥스트사이언스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 42.(주)넥스트사이언스
# CAGR :  23.03 %
# Sharpe :  0.65
# VOL :  79.42 %
# MDD :  81.25 %

# %%
df = yf.download('015260.KS', start = '2017-01-01', end='2019-12-31') #43.(주)에이엔피
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('43.(주)에이엔피')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 43.(주)에이엔피
# CAGR :  -49.07 %
# Sharpe :  -1.08
# VOL :  50.67 %
# MDD :  87.13 %

# %%
df = yf.download('005420.KS', start = '2017-01-01', end='2019-12-31') #44.코스모화학(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('44.코스모화학(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 44.코스모화학(주)
# CAGR :  21.45 %
# Sharpe :  0.63
# VOL :  72.79 %
# MDD :  85.63 %

# %%
df = yf.download('085310.KS', start = '2017-01-01', end='2019-12-31') #45.(주)엔케이
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('45.(주)엔케이')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 45.(주)엔케이
# CAGR :  -23.35 %
# Sharpe :  -0.17
# VOL :  58.4 %
# MDD :  63.62 %

# %%
df = yf.download('004410.KS', start = '2017-01-01', end='2019-12-31') #46.서울식품공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('46.서울식품공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 46.서울식품공업(주)
# CAGR :  4.48 %
# Sharpe :  0.31
# VOL :  44.77 %
# MDD :  64.5 %

# %%
df = yf.download('091090.KS', start = '2017-01-01', end='2019-12-31') #47.세원이앤씨(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('47.세원이앤씨(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 47.세원이앤씨(주)
# CAGR :  -1.23 %
# Sharpe :  0.24
# VOL :  54.49 %
# MDD :  66.27 %

# %%
df = yf.download('004540.KS', start = '2017-01-01', end='2019-12-31') #48.깨끗한나라(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('48.깨끗한나라(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 48.깨끗한나라(주)
# CAGR :  -26.38 %
# Sharpe :  -0.4
# VOL :  48.13 %
# MDD :  69.09 %

# %%
df = yf.download('082740.KS', start = '2017-01-01', end='2019-12-31') #49.에이치에스디엔진(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('49.에이치에스디엔진(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 49.에이치에스디엔진(주)
# CAGR :  11.32 %
# Sharpe :  0.49
# VOL :  54.77 %
# MDD :  62.86 %

# %%
df = yf.download('298050.KS', start = '2017-01-01', end='2019-12-31') #50.효성첨단소재(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('50.효성첨단소재(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 50.효성첨단소재(주)
# CAGR :  -22.58 %
# Sharpe :  -0.53
# VOL :  36.26 %
# MDD :  42.93 %

# %%
df = yf.download('001550.KS', start = '2017-01-01', end='2019-12-31') #51.(주)조비
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('51.(주)조비')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 51.(주)조비
# CAGR :  6.78 %
# Sharpe :  0.44
# VOL :  72.18 %
# MDD :  60.8 %

# %%
df = yf.download('298040.KS', start = '2017-01-01', end='2019-12-31') #52.효성중공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('52.효성중공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 52.효성중공업(주)
# CAGR :  -40.24 %
# Sharpe :  -1.0
# VOL :  42.47 %
# MDD :  61.5 %

# %%
df = yf.download('049800.KS', start = '2017-01-01', end='2019-12-31') #53.(주)우진플라임
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('53.(주)우진플라임')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 53.(주)우진플라임
# CAGR :  -24.93 %
# Sharpe :  -0.27
# VOL :  54.02 %
# MDD :  79.35 %

# %%
df = yf.download('272210.KS', start = '2017-01-01', end='2019-12-31') #54.한화시스템(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('54.한화시스템(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 54.한화시스템(주)
# CAGR :  -27.85 %
# Sharpe :  -0.71
# VOL :  37.52 %
# MDD :  17.21 %

# %%
df = yf.download('105840.KS', start = '2017-01-01', end='2019-12-31') #55.(주)우진
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('55.(주)우진')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 55.(주)우진
# CAGR :  -13.64 %
# Sharpe :  0.0
# VOL :  55.41 %
# MDD :  59.65 %

# %%
df = yf.download('213500.KS', start = '2017-01-01', end='2019-12-31') #56.한솔제지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('56.한솔제지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 56.한솔제지(주)
# CAGR :  -6.46 %
# Sharpe :  -0.14
# VOL :  25.43 %
# MDD :  35.23 %

# %%
df = yf.download('264900.KS', start = '2017-01-01', end='2019-12-31') #57.(주)크라운제과
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('57.(주)크라운제과')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 57.(주)크라운제과
# CAGR :  -28.89 %
# Sharpe :  -1.02
# VOL :  29.19 %
# MDD :  64.7 %

# %%
df = yf.download('001250.KS', start = '2017-01-01', end='2019-12-31') #58.(주)지에스글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('58.(주)지에스글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 58.(주)지에스글로벌
# CAGR :  -10.23 %
# Sharpe :  -0.13
# VOL :  35.46 %
# MDD :  53.18 %

# %%
df = yf.download('084870.KS', start = '2017-01-01', end='2019-12-31') #59.(주)티비에이치글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('59.(주)티비에이치글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 59.(주)티비에이치글로벌
# CAGR :  -32.36 %
# Sharpe :  -0.55
# VOL :  49.78 %
# MDD :  80.34 %

# %%
df = yf.download('088790.KS', start = '2017-01-01', end='2019-12-31') #60.(주)진도
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('60.(주)진도')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 60.(주)진도
# CAGR :  -9.15 %
# Sharpe :  -0.27
# VOL :  24.6 %
# MDD :  44.58 %

# %%
df = yf.download('042660.KS', start = '2017-01-01', end='2019-12-31') #61.대우조선해양(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('61.대우조선해양(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 61.대우조선해양(주)
# CAGR :  -15.12 %
# Sharpe :  0.01
# VOL :  51.64 %
# MDD :  68.97 %

# %%
df = yf.download('267290.KS', start = '2017-01-01', end='2019-12-31') #62.(주)경동도시가스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('62.(주)경동도시가스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 62.(주)경동도시가스
# CAGR :  -0.13 %
# Sharpe :  0.13
# VOL :  27.52 %
# MDD :  48.24 %

# %%
df = yf.download('006880.KS', start = '2017-01-01', end='2019-12-31') #63.신송홀딩스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('63.신송홀딩스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 63.신송홀딩스(주)
# CAGR :  -14.96 %
# Sharpe :  -0.3
# VOL :  34.73 %
# MDD :  48.46 %

# %%
df = yf.download('002780.KS', start = '2017-01-01', end='2019-12-31') #64.진흥기업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('64.진흥기업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 64.진흥기업(주)
# CAGR :  5.18 %
# Sharpe :  0.37
# VOL :  63.92 %
# MDD :  47.7 %

# %%
df = yf.download('183190.KS', start = '2017-01-01', end='2019-12-31') #65.아세아시멘트(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('65.아세아시멘트(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 65.아세아시멘트(주)
# CAGR :  2.81 %
# Sharpe :  0.29
# VOL :  50.15 %
# MDD :  63.88 %

# %%
df = yf.download('271980.KS', start = '2017-01-01', end='2019-12-31') #66.제일약품㈜
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('66.제일약품㈜')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 66.제일약품㈜
# CAGR :  -11.59 %
# Sharpe :  0.02
# VOL :  52.53 %
# MDD :  54.44 %

# %%
df = yf.download('028670.KS', start = '2017-01-01', end='2019-12-31') #67.팬오션(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('67.팬오션(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 67.팬오션(주)
# CAGR :  5.0 %
# Sharpe :  0.32
# VOL :  36.88 %
# MDD :  39.4 %

# %%
df = yf.download('000080.KS', start = '2017-01-01', end='2019-12-31') #68.하이트진로(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('68.하이트진로(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 68.하이트진로(주)
# CAGR :  16.1 %
# Sharpe :  0.71
# VOL :  25.65 %
# MDD :  41.73 %

# %%
df = yf.download('103590.KS', start = '2017-01-01', end='2019-12-31') #69.일진전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('69.일진전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 69.일진전기(주)
# CAGR :  -15.37 %
# Sharpe :  -0.32
# VOL :  34.27 %
# MDD :  65.84 %

# %%
df = yf.download('000520.KS', start = '2017-01-01', end='2019-12-31') #71.삼일제약(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('71.삼일제약(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 71.삼일제약(주)
# CAGR :  40.98 %
# Sharpe :  0.81
# VOL :  75.3 %
# MDD :  68.85 %

# %%
df = yf.download('000120.KS', start = '2017-01-01', end='2019-12-31') #72.씨제이대한통운(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('72.씨제이대한통운(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 72.씨제이대한통운(주)
# CAGR :  -4.93 %
# Sharpe :  -0.02
# VOL :  29.82 %
# MDD :  38.85 %

# %%
df = yf.download('012800.KS', start = '2017-01-01', end='2019-12-31') #73.(주)대창
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('73.(주)대창')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 73.(주)대창
# CAGR :  16.06 %
# Sharpe :  0.53
# VOL :  52.8 %
# MDD :  40.28 %

# %%
df = yf.download('013700.KS', start = '2017-01-01', end='2019-12-31') #74.(주)까뮤이앤씨
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('74.(주)까뮤이앤씨')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 74.(주)까뮤이앤씨
# CAGR :  7.24 %
# Sharpe :  0.37
# VOL :  41.24 %
# MDD :  42.09 %

# %%
df = yf.download('104700.KS', start = '2017-01-01', end='2019-12-31') #75.한국철강(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('75.한국철강(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 75.한국철강(주)
# CAGR :  -11.06 %
# Sharpe :  -0.25
# VOL :  29.65 %
# MDD :  46.65 %

# %%
df = yf.download('004980.KS', start = '2017-01-01', end='2019-12-31') #76.성신양회(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('76.성신양회(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 76.성신양회(주)
# CAGR :  1.27 %
# Sharpe :  0.35
# VOL :  67.47 %
# MDD :  61.07 %

# %%
df = yf.download('047810.KS', start = '2017-01-01', end='2019-12-31') #77.한국항공우주산업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('77.한국항공우주산업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 77.한국항공우주산업(주)
# CAGR :  -21.11 %
# Sharpe :  -0.34
# VOL :  42.49 %
# MDD :  59.24 %

# %%
df = yf.download('079980.KS', start = '2017-01-01', end='2019-12-31') #78.(주)휴비스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('78.(주)휴비스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 78.(주)휴비스
# CAGR :  -6.62 %
# Sharpe :  -0.06
# VOL :  31.31 %
# MDD :  56.05 %

# %%
df = yf.download('092780.KS', start = '2017-01-01', end='2019-12-31') #79.동양피스톤(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('79.동양피스톤(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 79.동양피스톤(주)
# CAGR :  3.47 %
# Sharpe :  0.28
# VOL :  39.75 %
# MDD :  49.35 %

# %%
df = yf.download('015020.KS', start = '2017-01-01', end='2019-12-31') #80.(주)이스타코
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('80.(주)이스타코')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 80.(주)이스타코
# CAGR :  -27.16 %
# Sharpe :  -0.35
# VOL :  52.47 %
# MDD :  73.3 %

# %%
df = yf.download('014130.KS', start = '2017-01-01', end='2019-12-31') #81.(주)한익스프레스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('81.(주)한익스프레스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 81.(주)한익스프레스
# CAGR :  -14.09 %
# Sharpe :  -0.08
# VOL :  48.78 %
# MDD :  55.05 %

# %%
df = yf.download('071090.KS', start = '2017-01-01', end='2019-12-31') #82.(주)하이스틸
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('82.(주)하이스틸')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 82.(주)하이스틸
# CAGR :  -2.5 %
# Sharpe :  0.26
# VOL :  60.72 %
# MDD :  74.71 %

# %%
df = yf.download('138490.KS', start = '2017-01-01', end='2019-12-31') #83.코오롱플라스틱(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('83.코오롱플라스틱(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 83.코오롱플라스틱(주)
# CAGR :  -10.64 %
# Sharpe :  -0.23
# VOL :  29.84 %
# MDD :  52.42 %

# %%
df = yf.download('024890.KS', start = '2017-01-01', end='2019-12-31') #84.대원화성(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('84.대원화성(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 84.대원화성(주)
# CAGR :  -17.85 %
# Sharpe :  -0.33
# VOL :  38.11 %
# MDD :  58.62 %

# %%
df = yf.download('180640.KS', start = '2017-01-01', end='2019-12-31') #85.(주)한진칼
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('85.(주)한진칼')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 85.(주)한진칼
# CAGR :  42.35 %
# Sharpe :  0.93
# VOL :  51.64 %
# MDD :  44.18 %

# %%
df = yf.download('014820.KS', start = '2017-01-01', end='2019-12-31') #86.동원시스템즈(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('86.동원시스템즈(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 86.동원시스템즈(주)
# CAGR :  -20.03 %
# Sharpe :  -0.46
# VOL :  35.46 %
# MDD :  62.27 %

# %%
df = yf.download('001380.KS', start = '2017-01-01', end='2019-12-31') #87.(주)에스지글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('87.(주)에스지글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 87.(주)에스지글로벌
# CAGR :  -20.7 %
# Sharpe :  0.03
# VOL :  71.4 %
# MDD :  83.74 %

# %%
df = yf.download('009580.KS', start = '2017-01-01', end='2019-12-31') #88.무림피앤피(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('88.무림피앤피(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 88.무림피앤피(주)
# CAGR :  5.88 %
# Sharpe :  0.34
# VOL :  34.16 %
# MDD :  62.81 %

# %%
df = yf.download('009470.KS', start = '2017-01-01', end='2019-12-31') #89.삼화전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('98. 삼화전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 98. 삼화전기(주)
# CAGR :  37.73 %
# Sharpe :  0.79
# VOL :  70.36 %
# MDD :  73.73 %

# %% [markdown]
# ## KOSPI BackTesting  살펴보기

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.31-py3-none-any.whl (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.6.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.1.5)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (2.23.0)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.31 requests-file-1.5.1

# %%
import FinanceDataReader as fdr
df1_krx = fdr.StockListing('KRX')

# %%
len(df1_krx)
# Out:
# 7096

# %%
import pandas as pd
import numpy as np

price_df1 = fdr.DataReader('KS11', '2017-01-01','2019-12-31')
price_df1['Close'].plot()

# %%
import FinanceDataReader as fdr
price_df1.head(5)
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2017-01-02  2026.16  2022.23  2031.79  2015.68  229880000.0 -0.0001
# 2017-01-03  2043.97  2034.31  2044.07  2028.47  268130000.0  0.0088
# 2017-01-04  2045.64  2046.29  2046.29  2040.61  371490000.0  0.0008
# 2017-01-05  2041.95  2045.52  2046.50  2039.49  541340000.0 -0.0018
# 2017-01-06  2049.12  2048.11  2051.84  2045.66  455350000.0  0.0035

# %%
price_df1.tail(5)
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-12-23  2203.71  2208.22  2209.20  2196.43  502030000.0 -0.0002
# 2019-12-24  2190.08  2206.23  2206.23  2187.58  569970000.0 -0.0062
# 2019-12-26  2197.93  2192.22  2198.01  2183.90  571310000.0  0.0036
# 2019-12-27  2204.21  2183.70  2215.55  2177.40  490170000.0  0.0029
# 2019-12-30  2197.67  2202.62  2208.04  2195.65  416400000.0 -0.0030

# %% [markdown]
# ## kposi 일별 수익률 계산하기 :  Buy &Hold Strategy

# %%
price_df1['daily_rtn'] = price_df1['Close'].pct_change()

# %%
#  Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df1['st_rtn'] = (1+price_df1['daily_rtn']).cumprod()

# %%
## mdd  필요 자료 
historical_max = price_df1['Close'].cummax()
daily_drawdown = price_df1['Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
historical_dd.plot()

# %%
CAGR = price_df1.loc['2019-12-30','st_rtn'] ** (252./len(price_df1.index)) -1
Sharpe = np.mean(price_df1['daily_rtn']) / np.std(price_df1['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df1['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# CAGR :  2.83 %
# Sharpe :  0.29
# VOL :  12.29 %
# MDD :  26.5 %

# %% [markdown]
# ## kospi 약 10년치 성과 평가를 꼭 기억 하시기 바랍니다!!!!!!!!!!!!!!!!!!!!!!!
#
# # ***** 9년간 -0.18% 인데 반해  MDD 25,85% 입니다.********
#
# # 만약 지난해 2020년을 포함했다면 MDD가 약 -52% 에 접근
#
# # 다만 특수 상황이라 배제했습니다.
#
# # 100%=-50% ,  -50%=100%    Don't forget it!!!!!!!!!!!!!!!

# %% [markdown]
# ## 다양한 Strategy 전략에 따른 BackTesting 에 코딩은 구글링하면 쉽게 얻을 수 있음
#
# # 저명한 퀀트 전략에 대한 알고리즘 필요한 분은 개별적으로 얘기하시면 공유
#
# # 드릴께요 ^^
