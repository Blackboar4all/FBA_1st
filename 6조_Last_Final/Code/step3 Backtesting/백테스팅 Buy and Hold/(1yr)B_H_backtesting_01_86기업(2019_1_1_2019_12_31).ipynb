# %% [markdown]
# # Buy &Hold Strategy

# %%
# CAGR-연복리수익률
# MDD-최대손실가능수익률=(최고가-최저가)/최고가
# Sharpe Ratio(펀드수익률-벤치마크수익률)/(해당펀드수익률표준편차)

## Performance Measure
# CAGR : 연복리수익률, 일별 data를 사용 한 경우 -> 전체연도를 계산하는 경우 전체 data 기간을 252영업일로 나눈 역수를 제곱(승)을 한 후 -1 을 한다.
# MDD(Max-DrawDown) : 최대손실가능수익률
# VOL : 연 주가수익률 표준편차 = 일변 주가수익률 X  252일 제곱근 (영업일수 고려, IID 가정 )
# Sharpe : 총위험 1단위당 초과수익률 ( 위험을 고려한 초과수익)

# %%
# !pip install yfinance
import numpy as np
import pandas as pd
import warnings
import os
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.67)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.7.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)

# %%
df = yf.download('028050.KS', start = '2019-01-01', end='2019-12-31')  #01. 삼성엔지니어링(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('01.삼성엔지니어링(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 01.삼성엔지니어링(주)
# CAGR :  10.29 %
# Sharpe :  0.49
# VOL :  27.83 %
# MDD :  16.67 %

# %%
df = yf.download('071970.KS', start = '2019-01-01', end='2019-12-31') #02.STX중공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('02. STX중공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 02. STX중공업(주)
# CAGR :  -46.25 %
# Sharpe :  -0.68
# VOL :  63.75 %
# MDD :  70.06 %

# %%
df = yf.download('071950.KS', start = '2019-01-01', end='2019-12-31') #03. (주)코아스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('03. (주)코아스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 03. (주)코아스
# CAGR :  -2.33 %
# Sharpe :  0.3
# VOL :  67.77 %
# MDD :  46.57 %

# %%
df = yf.download('306200.KS', start = '2019-01-01', end='2019-12-31') #04. (주)세아제강
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('04. (주)세아제강')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 04. (주)세아제강
# CAGR :  11.28 %
# Sharpe :  0.52
# VOL :  27.79 %
# MDD :  22.22 %

# %%
df = yf.download('007570.KS', start = '2019-01-01', end='2019-12-31') #05. 일양약품(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('05.일양약품(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 05.일양약품(주)
# CAGR :  -17.01 %
# Sharpe :  -0.45
# VOL :  30.68 %
# MDD :  42.14 %

# %%
df = yf.download('003070.KS', start = '2019-01-01', end='2019-12-31') #06. 코오롱글로벌(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('06. 코오롱글로벌(주)') 
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 06. 코오롱글로벌(주)
# CAGR :  42.48 %
# Sharpe :  1.03
# VOL :  43.64 %
# MDD :  35.02 %

# %%
df = yf.download('012280.KS', start = '2019-01-01', end='2019-12-31') #07.영화금속(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('07. 영화금속(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 07. 영화금속(주)
# CAGR :  23.25 %
# Sharpe :  0.76
# VOL :  35.99 %
# MDD :  27.98 %

# %%
df = yf.download('004920.KS', start = '2019-01-01', end='2019-12-31') #08. (주)씨아이테크
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('08. (주)씨아이테크')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 08. (주)씨아이테크
# CAGR :  -11.32 %
# Sharpe :  -0.19
# VOL :  33.82 %
# MDD :  31.9 %

# %%
df = yf.download('027970.KS', start = '2019-01-01', end='2019-12-31') # 09.세하(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('09. 세하(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 09. 세하(주)
# CAGR :  85.81 %
# Sharpe :  1.52
# VOL :  48.44 %
# MDD :  24.84 %

# %%
df = yf.download('010820.KS', start = '2019-01-01', end='2019-12-31') #10. 퍼스텍(주) 
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('10. 퍼스텍(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 10. 퍼스텍(주)
# CAGR :  -25.39 %
# Sharpe :  -0.41
# VOL :  46.08 %
# MDD :  52.27 %

# %%
df = yf.download('008970.KS', start = '2019-01-01', end='2019-12-31') #11. 동양철관(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('11. 동양철관(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 11. 동양철관(주)
# CAGR :  -29.11 %
# Sharpe :  -0.5
# VOL :  46.85 %
# MDD :  47.95 %

# %%
df = yf.download('073240.KS', start = '2019-01-01', end='2019-12-31') #12. 금호타이어(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('12. 금호타이어(주) ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 12. 금호타이어(주)
# CAGR :  -19.75 %
# Sharpe :  -0.71
# VOL :  26.26 %
# MDD :  29.64 %

# %%
df = yf.download('015590.KS', start = '2019-01-01', end='2019-12-31') #13.(주)큐로
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('13. (주)큐로 ')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 13. (주)큐로
# CAGR :  116.7 %
# Sharpe :  1.71
# VOL :  53.8 %
# MDD :  35.58 %

# %%
df = yf.download('008040.KS', start = '2019-01-01', end='2019-12-31') #14.사조동아원(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('14. 사조동아원(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 14. 사조동아원(주)
# CAGR :  -16.61 %
# Sharpe :  -0.11
# VOL :  51.73 %
# MDD :  42.79 %

# %%
df = yf.download('004140.KS', start = '2019-01-01', end='2019-12-31') #15. (주)동방
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('15. (주)동방')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 15. (주)동방
# CAGR :  14.71 %
# Sharpe :  0.52
# VOL :  49.46 %
# MDD :  36.02 %

# %%
df = yf.download('000140.KS', start = '2019-01-01', end='2019-12-31') #16. 하이트진로홀딩스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('16. 하이트진로홀딩스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 16. 하이트진로홀딩스(주)
# CAGR :  96.23 %
# Sharpe :  1.62
# VOL :  48.77 %
# MDD :  18.22 %

# %%
df = yf.download('004710.KS', start = '2019-01-01', end='2019-12-31') #17. 한솔테크닉스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('17. 한솔테크닉스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 17. 한솔테크닉스(주)
# CAGR :  59.49 %
# Sharpe :  1.15
# VOL :  53.01 %
# MDD :  28.25 %

# %%
df = yf.download('002410.KS', start = '2019-01-01', end='2019-12-31') #18. 범양건영(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('18. 범양건영(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 18. 범양건영(주)
# CAGR :  115.56 %
# Sharpe :  1.69
# VOL :  53.7 %
# MDD :  32.26 %

# %%
df = yf.download('298000.KS', start = '2019-01-01', end='2019-12-31') #19.효성화학(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('19.효성화학(주))')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 19.효성화학(주))
# CAGR :  3.61 %
# Sharpe :  0.27
# VOL :  30.72 %
# MDD :  24.79 %

# %%
df = yf.download('009200.KS', start = '2019-01-01', end='2019-12-31') #20.무림페이퍼(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('20.무림페이퍼(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 20.무림페이퍼(주)
# CAGR :  -8.65 %
# Sharpe :  -0.23
# VOL :  25.52 %
# MDD :  33.51 %

# %%
df = yf.download('298020.KS', start = '2019-01-01', end='2019-12-31') #21.효성티앤씨(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('21.효성티앤씨(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 21.효성티앤씨(주)
# CAGR :  -15.75 %
# Sharpe :  -0.47
# VOL :  28.05 %
# MDD :  28.08 %

# %%
df = yf.download('030720.KS', start = '2019-01-01', end='2019-12-31') #22.동원수산(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('22.동원수산(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 22.동원수산(주)
# CAGR :  14.02 %
# Sharpe :  0.5
# VOL :  48.35 %
# MDD :  28.2 %

# %%
df = yf.download('001230.KS', start = '2019-01-01', end='2019-12-31') #23.동국제강(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('23.동국제강(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 23.동국제강(주)
# CAGR :  -16.07 %
# Sharpe :  -0.39
# VOL :  32.09 %
# MDD :  33.76 %

# %%
df = yf.download('272550.KS', start = '2019-01-01', end='2019-12-31') #24.(주)삼양패키징
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('24.(주)삼양패키징')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 24.(주)삼양패키징
# CAGR :  -8.11 %
# Sharpe :  -0.25
# VOL :  23.15 %
# MDD :  22.31 %

# %%
df = yf.download('012030.KS', start = '2019-01-01', end='2019-12-31') #25.(주)디비아이엔씨
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('25.(주)디비아이엔씨')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 25.(주)디비아이엔씨
# CAGR :  6.18 %
# Sharpe :  0.35
# VOL :  28.08 %
# MDD :  25.27 %

# %%
df = yf.download('044450.KS', start = '2019-01-01', end='2019-12-31') #26.(주)케이에스에스해운
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('26.(주)케이에스에스해운')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 26.(주)케이에스에스해운
# CAGR :  25.71 %
# Sharpe :  1.22
# VOL :  20.63 %
# MDD :  11.96 %

# %%
df = yf.download('002990.KS', start = '2019-01-01', end='2019-12-31') #27. 금호산업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('27.금호산업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 27.금호산업(주)
# CAGR :  5.87 %
# Sharpe :  0.39
# VOL :  57.64 %
# MDD :  33.23 %

# %%
df = yf.download('294870.KS', start = '2019-01-01', end='2019-12-31') #28.에이치디씨현대산업개발(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('28.에이치디씨현대산업개발(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 28.에이치디씨현대산업개발(주)
# CAGR :  -46.88 %
# Sharpe :  -1.58
# VOL :  35.94 %
# MDD :  51.63 %

# %%
df = yf.download('204320.KS', start = '2019-01-01', end='2019-12-31') #29.(주)만도
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('29.(주)만도')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 29.(주)만도
# CAGR :  24.63 %
# Sharpe :  0.76
# VOL :  39.26 %
# MDD :  26.15 %

# %%
df = yf.download('120110.KS', start = '2019-01-01', end='2019-12-31') #31.코오롱인더스트리(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('31.코오롱인더스트리(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 31.코오롱인더스트리(주)
# CAGR :  -10.72 %
# Sharpe :  -0.22
# VOL :  30.57 %
# MDD :  39.64 %

# %%
df = yf.download('001780.KS', start = '2019-01-01', end='2019-12-31') #32.(주)알루코
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('32.(주)알루코')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 32.(주)알루코
# CAGR :  -1.65 %
# Sharpe :  0.12
# VOL :  33.25 %
# MDD :  36.48 %

# %%
df = yf.download('005090.KS', start = '2019-01-01', end='2019-12-31') #33.에스지씨에너지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('33.에스지씨에너지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 33.에스지씨에너지(주)
# CAGR :  8.2 %
# Sharpe :  0.43
# VOL :  26.29 %
# MDD :  33.18 %

# %%
df = yf.download('002870.KS', start = '2019-01-01', end='2019-12-31') #34.신풍제지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('34.신풍제지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 34.신풍제지(주)
# CAGR :  20.14 %
# Sharpe :  0.76
# VOL :  30.18 %
# MDD :  30.92 %

# %%
df = yf.download('011070.KS', start = '2019-01-01', end='2019-12-31') #35.LG이노텍(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('35.LG이노텍(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 35.LG이노텍(주)
# CAGR :  69.76 %
# Sharpe :  1.52
# VOL :  40.44 %
# MDD :  28.34 %

# %%
df = yf.download('170900.KS', start = '2019-01-01', end='2019-12-31') #36.동아에스티(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('36.동아에스티(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 36.동아에스티(주)
# CAGR :  15.25 %
# Sharpe :  0.62
# VOL :  30.87 %
# MDD :  26.7 %

# %%
df = yf.download('163560.KS', start = '2019-01-01', end='2019-12-31') #37.동일고무벨트(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('37.동일고무벨트(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 37.동일고무벨트(주)
# CAGR :  -8.72 %
# Sharpe :  -0.32
# VOL :  21.69 %
# MDD :  28.22 %

# %%
df = yf.download('084680.KS', start = '2019-01-01', end='2019-12-31') #38.(주)이월드
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('38.(주)이월드')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 38.(주)이월드
# CAGR :  117.59 %
# Sharpe :  1.38
# VOL :  76.94 %
# MDD :  28.48 %

# %%
df = yf.download('003480.KS', start = '2019-01-01', end='2019-12-31') #39.(주)한진중공업홀딩스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('39.(주)한진중공업홀딩스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 39.(주)한진중공업홀딩스
# CAGR :  -11.41 %
# Sharpe :  0.09
# VOL :  61.47 %
# MDD :  47.24 %

# %%
df = yf.download('001210.KS', start = '2019-01-01', end='2019-12-31') #40.금호전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('40.금호전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 40.금호전기(주)
# CAGR :  -35.07 %
# Sharpe :  -0.24
# VOL :  73.37 %
# MDD :  70.34 %

# %%
df = yf.download('010600.KS', start = '2019-01-01', end='2019-12-31') #41.웰바이오텍(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('41.웰바이오텍(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 41.웰바이오텍(주)
# CAGR :  -63.21 %
# Sharpe :  -0.83
# VOL :  82.03 %
# MDD :  65.52 %

# %%
df = yf.download('003580.KS', start = '2019-01-01', end='2019-12-31') #42.(주)넥스트사이언스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('42.(주)넥스트사이언스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 42.(주)넥스트사이언스
# CAGR :  32.43 %
# Sharpe :  0.75
# VOL :  88.06 %
# MDD :  62.55 %

# %%
df = yf.download('015260.KS', start = '2019-01-01', end='2019-12-31') #43.(주)에이엔피
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('43.(주)에이엔피')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 43.(주)에이엔피
# CAGR :  -10.96 %
# Sharpe :  -0.04
# VOL :  44.74 %
# MDD :  43.69 %

# %%
df = yf.download('005420.KS', start = '2019-01-01', end='2019-12-31') #44.코스모화학(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('44.코스모화학(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 44.코스모화학(주)
# CAGR :  -41.03 %
# Sharpe :  -0.36
# VOL :  73.5 %
# MDD :  73.59 %

# %%
df = yf.download('085310.KS', start = '2019-01-01', end='2019-12-31') #45.(주)엔케이
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('45.(주)엔케이')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 45.(주)엔케이
# CAGR :  -39.14 %
# Sharpe :  -0.81
# VOL :  47.63 %
# MDD :  55.02 %

# %%
df = yf.download('004410.KS', start = '2019-01-01', end='2019-12-31') #46.서울식품공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('46.서울식품공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 46.서울식품공업(주)
# CAGR :  -0.58 %
# Sharpe :  0.11
# VOL :  26.15 %
# MDD :  25.24 %

# %%
df = yf.download('091090.KS', start = '2019-01-01', end='2019-12-31') #47.세원이앤씨(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('47.세원이앤씨(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 47.세원이앤씨(주)
# CAGR :  -20.43 %
# Sharpe :  -0.36
# VOL :  40.84 %
# MDD :  46.29 %

# %%
df = yf.download('004540.KS', start = '2019-01-01', end='2019-12-31') #48.깨끗한나라(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('48.깨끗한나라(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 48.깨끗한나라(주)
# CAGR :  -22.62 %
# Sharpe :  -0.18
# VOL :  56.05 %
# MDD :  38.62 %

# %%
df = yf.download('082740.KS', start = '2019-01-01', end='2019-12-31') #49.에이치에스디엔진(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('49.에이치에스디엔진(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 49.에이치에스디엔진(주)
# CAGR :  -12.63 %
# Sharpe :  -0.05
# VOL :  47.02 %
# MDD :  60.64 %

# %%
df = yf.download('298050.KS', start = '2019-01-01', end='2019-12-31') #50.효성첨단소재(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('50.효성첨단소재(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 50.효성첨단소재(주)
# CAGR :  8.5 %
# Sharpe :  0.41
# VOL :  33.62 %
# MDD :  29.11 %

# %%
df = yf.download('001550.KS', start = '2019-01-01', end='2019-12-31') #51.(주)조비
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('51.(주)조비')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 51.(주)조비
# CAGR :  -32.33 %
# Sharpe :  -0.35
# VOL :  60.32 %
# MDD :  54.84 %

# %%
df = yf.download('298040.KS', start = '2019-01-01', end='2019-12-31') #52.효성중공업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('52.효성중공업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 52.효성중공업(주)
# CAGR :  -37.25 %
# Sharpe :  -1.07
# VOL :  37.41 %
# MDD :  50.25 %

# %%
df = yf.download('049800.KS', start = '2019-01-01', end='2019-12-31') #53.(주)우진플라임
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('53.(주)우진플라임')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 53.(주)우진플라임
# CAGR :  -37.91 %
# Sharpe :  -0.7
# VOL :  51.05 %
# MDD :  56.93 %

# %%
df = yf.download('272210.KS', start = '2019-01-01', end='2019-12-31') #54.한화시스템(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('54.한화시스템(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 54.한화시스템(주)
# CAGR :  -27.85 %
# Sharpe :  -0.71
# VOL :  37.52 %
# MDD :  17.21 %

# %%
df = yf.download('105840.KS', start = '2019-01-01', end='2019-12-31') #55.(주)우진
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('55.(주)우진')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 55.(주)우진
# CAGR :  -10.43 %
# Sharpe :  0.17
# VOL :  69.06 %
# MDD :  46.41 %

# %%
df = yf.download('213500.KS', start = '2019-01-01', end='2019-12-31') #56.한솔제지(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('56.한솔제지(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 56.한솔제지(주)
# CAGR :  -10.82 %
# Sharpe :  -0.29
# VOL :  27.03 %
# MDD :  26.08 %

# %%
df = yf.download('264900.KS', start = '2019-01-01', end='2019-12-31') #57.(주)크라운제과
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('57.(주)크라운제과')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 57.(주)크라운제과
# CAGR :  -5.28 %
# Sharpe :  -0.18
# VOL :  19.8 %
# MDD :  27.05 %

# %%
df = yf.download('001250.KS', start = '2019-01-01', end='2019-12-31') #58.(주)지에스글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('58.(주)지에스글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 58.(주)지에스글로벌
# CAGR :  -7.68 %
# Sharpe :  -0.18
# VOL :  26.02 %
# MDD :  26.7 %

# %%
df = yf.download('084870.KS', start = '2019-01-01', end='2019-12-31') #59.(주)티비에이치글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('59.(주)티비에이치글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 59.(주)티비에이치글로벌
# CAGR :  -8.21 %
# Sharpe :  0.18
# VOL :  66.2 %
# MDD :  32.58 %

# %%
df = yf.download('088790.KS', start = '2019-01-01', end='2019-12-31') #60.(주)진도
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('60.(주)진도')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 60.(주)진도
# CAGR :  -22.17 %
# Sharpe :  -1.02
# VOL :  22.2 %
# MDD :  31.91 %

# %%
df = yf.download('042660.KS', start = '2019-01-01', end='2019-12-31') #61.대우조선해양(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('61.대우조선해양(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 61.대우조선해양(주)
# CAGR :  -16.73 %
# Sharpe :  -0.39
# VOL :  33.19 %
# MDD :  35.27 %

# %%
df = yf.download('267290.KS', start = '2019-01-01', end='2019-12-31') #62.(주)경동도시가스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('62.(주)경동도시가스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 62.(주)경동도시가스
# CAGR :  -16.97 %
# Sharpe :  -0.66
# VOL :  23.95 %
# MDD :  36.17 %

# %%
df = yf.download('006880.KS', start = '2019-01-01', end='2019-12-31') #63.신송홀딩스(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('63.신송홀딩스(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 63.신송홀딩스(주)
# CAGR :  -8.93 %
# Sharpe :  -0.05
# VOL :  38.87 %
# MDD :  37.17 %

# %%
df = yf.download('002780.KS', start = '2019-01-01', end='2019-12-31') #64.진흥기업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('64.진흥기업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 64.진흥기업(주)
# CAGR :  13.29 %
# Sharpe :  0.5
# VOL :  71.7 %
# MDD :  41.61 %

# %%
df = yf.download('183190.KS', start = '2019-01-01', end='2019-12-31') #65.아세아시멘트(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('65.아세아시멘트(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 65.아세아시멘트(주)
# CAGR :  -26.35 %
# Sharpe :  -0.68
# VOL :  35.95 %
# MDD :  46.95 %

# %%
df = yf.download('271980.KS', start = '2019-01-01', end='2019-12-31') #66.제일약품㈜
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('66.제일약품㈜')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 66.제일약품㈜
# CAGR :  -18.71 %
# Sharpe :  -0.33
# VOL :  39.66 %
# MDD :  47.9 %

# %%
df = yf.download('028670.KS', start = '2019-01-01', end='2019-12-31') #67.팬오션(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('67.팬오션(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 67.팬오션(주)
# CAGR :  2.31 %
# Sharpe :  0.22
# VOL :  27.58 %
# MDD :  18.29 %

# %%
df = yf.download('000080.KS', start = '2019-01-01', end='2019-12-31') #68.하이트진로(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('68.하이트진로(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 68.하이트진로(주)
# CAGR :  85.19 %
# Sharpe :  2.41
# VOL :  27.29 %
# MDD :  11.89 %

# %%
df = yf.download('103590.KS', start = '2019-01-01', end='2019-12-31') #69.일진전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('69.일진전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 69.일진전기(주)
# CAGR :  2.07 %
# Sharpe :  0.22
# VOL :  31.59 %
# MDD :  38.58 %

# %%
df = yf.download('000520.KS', start = '2019-01-01', end='2019-12-31') #71.삼일제약(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('71.삼일제약(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 71.삼일제약(주)
# CAGR :  4.03 %
# Sharpe :  0.36
# VOL :  57.39 %
# MDD :  56.92 %

# %%
df = yf.download('000120.KS', start = '2019-01-01', end='2019-12-31') #72.씨제이대한통운(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('72.씨제이대한통운(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 72.씨제이대한통운(주)
# CAGR :  -7.07 %
# Sharpe :  -0.11
# VOL :  28.89 %
# MDD :  31.5 %

# %%
df = yf.download('012800.KS', start = '2019-01-01', end='2019-12-31') #73.(주)대창
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('73.(주)대창')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 73.(주)대창
# CAGR :  58.6 %
# Sharpe :  0.96
# VOL :  76.8 %
# MDD :  40.28 %

# %%
df = yf.download('013700.KS', start = '2019-01-01', end='2019-12-31') #74.(주)까뮤이앤씨
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('74.(주)까뮤이앤씨')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 74.(주)까뮤이앤씨
# CAGR :  -9.91 %
# Sharpe :  -0.06
# VOL :  41.05 %
# MDD :  26.24 %

# %%
df = yf.download('104700.KS', start = '2019-01-01', end='2019-12-31') #75.한국철강(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('75.한국철강(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 75.한국철강(주)
# CAGR :  -9.05 %
# Sharpe :  -0.26
# VOL :  24.98 %
# MDD :  29.62 %

# %%
df = yf.download('004980.KS', start = '2019-01-01', end='2019-12-31') #76.성신양회(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('76.성신양회(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 76.성신양회(주)
# CAGR :  -37.01 %
# Sharpe :  -0.63
# VOL :  52.06 %
# MDD :  55.43 %

# %%
df = yf.download('047810.KS', start = '2019-01-01', end='2019-12-31') #77.한국항공우주산업(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('77.한국항공우주산업(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 77.한국항공우주산업(주)
# CAGR :  6.18 %
# Sharpe :  0.36
# VOL :  25.46 %
# MDD :  19.47 %

# %%
df = yf.download('079980.KS', start = '2019-01-01', end='2019-12-31') #78.(주)휴비스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('78.(주)휴비스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 78.(주)휴비스
# CAGR :  -16.49 %
# Sharpe :  -0.56
# VOL :  26.1 %
# MDD :  33.72 %

# %%
df = yf.download('092780.KS', start = '2019-01-01', end='2019-12-31') #79.동양피스톤(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('79.동양피스톤(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 79.동양피스톤(주)
# CAGR :  1.78 %
# Sharpe :  0.26
# VOL :  45.88 %
# MDD :  49.35 %

# %%
df = yf.download('015020.KS', start = '2019-01-01', end='2019-12-31') #80.(주)이스타코
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('80.(주)이스타코')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 80.(주)이스타코
# CAGR :  13.44 %
# Sharpe :  0.55
# VOL :  32.06 %
# MDD :  34.03 %

# %%
df = yf.download('014130.KS', start = '2019-01-01', end='2019-12-31') #81.(주)한익스프레스
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('81.(주)한익스프레스')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 81.(주)한익스프레스
# CAGR :  4.88 %
# Sharpe :  0.39
# VOL :  67.56 %
# MDD :  55.05 %

# %%
df = yf.download('071090.KS', start = '2019-01-01', end='2019-12-31') #82.(주)하이스틸
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('82.(주)하이스틸')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 82.(주)하이스틸
# CAGR :  -26.51 %
# Sharpe :  -0.44
# VOL :  46.15 %
# MDD :  54.61 %

# %%
df = yf.download('138490.KS', start = '2019-01-01', end='2019-12-31') #83.코오롱플라스틱(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('83.코오롱플라스틱(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 83.코오롱플라스틱(주)
# CAGR :  -20.59 %
# Sharpe :  -0.53
# VOL :  33.62 %
# MDD :  37.28 %

# %%
df = yf.download('024890.KS', start = '2019-01-01', end='2019-12-31') #84.대원화성(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('84.대원화성(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 84.대원화성(주)
# CAGR :  -20.07 %
# Sharpe :  -0.51
# VOL :  33.42 %
# MDD :  40.59 %

# %%
df = yf.download('180640.KS', start = '2019-01-01', end='2019-12-31') #85.(주)한진칼
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('85.(주)한진칼')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 85.(주)한진칼
# CAGR :  38.25 %
# Sharpe :  0.81
# VOL :  64.0 %
# MDD :  44.18 %

# %%
df = yf.download('014820.KS', start = '2019-01-01', end='2019-12-31') #86.동원시스템즈(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('86.동원시스템즈(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 86.동원시스템즈(주)
# CAGR :  10.0 %
# Sharpe :  0.44
# VOL :  36.96 %
# MDD :  36.69 %

# %%
df = yf.download('001380.KS', start = '2019-01-01', end='2019-12-31') #87.(주)에스지글로벌
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('87.(주)에스지글로벌')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 87.(주)에스지글로벌
# CAGR :  -41.27 %
# Sharpe :  -0.94
# VOL :  45.7 %
# MDD :  46.17 %

# %%
df = yf.download('009580.KS', start = '2019-01-01', end='2019-12-31') #88.무림피앤피(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('88.무림피앤피(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 88.무림피앤피(주)
# CAGR :  -26.47 %
# Sharpe :  -0.71
# VOL :  35.05 %
# MDD :  42.45 %

# %%
df = yf.download('009470.KS', start = '2019-01-01', end='2019-12-31') #89.삼화전기(주)
price_df = df.loc[:,['Adj Close']].copy()
price_df['daily_rtn'] = price_df['Adj Close'].pct_change() # Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
historical_max = price_df['Adj Close'].cummax()
daily_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
CAGR = price_df.loc['2019-12-30','st_rtn'] ** (252./len(price_df.index)) -1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('98. 삼화전기(주)')
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# 98. 삼화전기(주)
# CAGR :  -28.45 %
# Sharpe :  -0.37
# VOL :  53.71 %
# MDD :  48.32 %

# %% [markdown]
# ## KOSPI BackTesting  살펴보기

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.31-py3-none-any.whl (17 kB)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (2.23.0)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from finance-datareader) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.31 requests-file-1.5.1

# %%
import FinanceDataReader as fdr
df1_krx = fdr.StockListing('KRX')

# %%
len(df1_krx)
# Out:
# 6379

# %%
import pandas as pd
import numpy as np

price_df1 = fdr.DataReader('KS11', '2019-01-01','2019-12-31')
price_df1['Close'].plot()

# %%
import FinanceDataReader as fdr
price_df1.head(5)
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-01-02  2010.00  2050.55  2053.45  2004.27  326370000.0 -0.0152
# 2019-01-03  1993.70  2011.81  2014.72  1991.65  427980000.0 -0.0081
# 2019-01-04  2010.25  1992.40  2011.56  1984.53  408990000.0  0.0083
# 2019-01-07  2037.10  2034.24  2048.06  2030.90  440190000.0  0.0134
# 2019-01-08  2025.27  2038.68  2042.70  2023.59  397830000.0 -0.0058

# %%
price_df1.tail(5)
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-12-23  2203.71  2208.22  2209.20  2196.43  502030000.0 -0.0002
# 2019-12-24  2190.08  2206.23  2206.23  2187.58  569970000.0 -0.0062
# 2019-12-26  2197.93  2192.22  2198.01  2183.90  571310000.0  0.0036
# 2019-12-27  2204.21  2183.70  2215.55  2177.40  490170000.0  0.0029
# 2019-12-30  2197.67  2202.62  2208.04  2195.65  416400000.0 -0.0030

# %% [markdown]
# ## kposi 일별 수익률 계산하기 :  Buy &Hold Strategy

# %%
price_df1['daily_rtn'] = price_df1['Close'].pct_change()

# %%
#  Buy & Hold Strategy 누적 곱을 계산 한 사례  판다스 cumprod() 함수 사용
price_df1['st_rtn'] = (1+price_df1['daily_rtn']).cumprod()

# %%
## mdd  필요 자료 
historical_max = price_df1['Close'].cummax()
daily_drawdown = price_df1['Close'] / historical_max - 1.0
historical_dd = daily_drawdown.cummin()
historical_dd.plot()

# %%
CAGR = price_df1.loc['2019-12-30','st_rtn'] ** (252./len(price_df1.index)) -1
Sharpe = np.mean(price_df1['daily_rtn']) / np.std(price_df1['daily_rtn']) * np.sqrt(252.)
VOL = np.std(price_df1['daily_rtn']) * np.sqrt(252.)
MDD = historical_dd.min()
print('CAGR : ',round(CAGR*100,2),'%')
print('Sharpe : ',round(Sharpe,2))
print('VOL : ',round(VOL*100,2),'%')
print('MDD : ',round(-1*MDD*100,2),'%')
# Out:
# CAGR :  9.58 %
# Sharpe :  0.8
# VOL :  12.46 %
# MDD :  15.07 %

# %% [markdown]
# ## kospi 약 10년치 성과 평가를 꼭 기억 하시기 바랍니다!!!!!!!!!!!!!!!!!!!!!!!
#
# # ***** 9년간 -0.18% 인데 반해  MDD 25,85% 입니다.********
#
# # 만약 지난해 2020년을 포함했다면 MDD가 약 -52% 에 접근
#
# # 다만 특수 상황이라 배제했습니다.
#
# # 100%=-50% ,  -50%=100%    Don't forget it!!!!!!!!!!!!!!!

# %% [markdown]
# ## 다양한 Strategy 전략에 따른 BackTesting 에 코딩은 구글링하면 쉽게 얻을 수 있음
#
# # 저명한 퀀트 전략에 대한 알고리즘 필요한 분은 개별적으로 얘기하시면 공유
#
# # 드릴께요 ^^
