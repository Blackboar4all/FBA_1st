# %%
# !pip install yfinance
import numpy as np
import pandas as pd
import warnings
import os
import yfinance as yf
import matplotlib.pylab as plt
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.67-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 11.4 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.10.8)
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.7.1 yfinance-0.1.67

# %%
A = pd.read_excel('/content/Backtesting(2009~2019).xlsx', dtype={'거래소코드':str})

# %%
A
# Out:
#             회사명   거래소코드  Z(K2) Score  F Score           시가총액
# 0   (주)한진중공업홀딩스  003480   -37.922085        6    76482213080
# 1       금호전기(주)  001210   -33.796449        6    44043971400
# 2     STX중공업(주)  071970   -25.506715        8    85789688205
# 3      (주)씨아이테크  004920   -22.017654        7    24829240728
# 4      웰바이오텍(주)  010600   -19.829073        6    93977081610
# ..          ...     ...          ...      ...            ...
# 81    (주)에스지글로벌  001380     0.466548        6    77563336425
# 82     무림피앤피(주)  009580     0.542649        6   263506168900
# 83     동아에스티(주)  170900     0.638220        7  1004820292000
# 84    동일고무벨트(주)  163560     0.652069        7    73558500000
# 85       (주)이월드  084680     0.743639        7   757245070620
#
# [86 rows x 5 columns]

# %%
A['거래소코드'] = A['거래소코드'].astype(str) + '.KS'

# %%
def df2dict(A):
     
    df_dict = []
    
    for k, v in zip(A.iloc[:, 0], A.iloc[:, 1]): # 행 전체 열은 0,1번열 즉 회사명, 거래소코드 라네! .....
        temp = {}
        temp[k]=v
        df_dict.append(temp)

    return df_dict

# %%
stocks=df2dict(A)

# %%
stocks
# Out:
# [{'(주)한진중공업홀딩스': '003480.KS'},
#  {'금호전기(주)': '001210.KS'},
#  {'STX중공업(주)': '071970.KS'},
#  {'(주)씨아이테크': '004920.KS'},
#  {'웰바이오텍(주)': '010600.KS'},
#  {'(주)넥스트사이언스': '003580.KS'},
#  {'세하(주)': '027970.KS'},
#  {'(주)에이엔피': '015260.KS'},
#  {'코스모화학(주)': '005420.KS'},
#  {'(주)엔케이': '085310.KS'},
#  {'동양철관(주)': '008970.KS'},
#  {'서울식품공업(주)': '004410.KS'},
#  {'세원이앤씨(주)': '091090.KS'},
#  {'금호타이어(주)': '073240.KS'},
#  {'깨끗한나라(주)': '004540.KS'},
#  {'(주)큐로': '015590.KS'},
#  {'에이치에스디엔진(주)': '082740.KS'},
#  {'효성첨단소재(주)': '298050.KS'},
#  {'사조동아원(주)': '008040.KS'},
#  {'(주)코아스': '071950.KS'},
#  {'(주)조비': '001550.KS'},
#  {'(주)동방': '004140.KS'},
#  {'효성중공업(주)': '298040.KS'},
#  {'(주)세아제강': '306200.KS'},
#  {'하이트진로홀딩스(주)': '000140.KS'},
#  {'(주)우진플라임': '049800.KS'},
#  {'한솔테크닉스(주)': '004710.KS'},
#  {'범양건영(주)': '002410.KS'},
#  {'일양약품(주)': '007570.KS'},
#  {'한화시스템(주)': '272210.KS'},
#  {'(주)우진': '105840.KS'},
#  {'한솔제지(주)': '213500.KS'},
#  {'(주)크라운제과': '264900.KS'},
#  {'(주)지에스글로벌': '001250.KS'},
#  {'(주)티비에이치글로벌': '084870.KS'},
#  {'효성화학(주)': '298000.KS'},
#  {'(주)진도': '088790.KS'},
#  {'대우조선해양(주)': '042660.KS'},
#  {'무림페이퍼(주)': '009200.KS'},
#  {'효성티앤씨(주)': '298020.KS'},
#  {'(주)경동도시가스': '267290.KS'},
#  {'신송홀딩스(주)': '006880.KS'},
#  {'동원수산(주)': '030720.KS'},
#  {'진흥기업(주)': '002780.KS'},
#  {'아세아시멘트(주)': '183190.KS'},
#  {'제일약품(주)': '271980.KS'},
#  {'팬오션(주)': '028670.KS'},
#  {'하이트진로(주)': '000080.KS'},
#  {'삼성엔지니어링(주)': '028050.KS'},
#  {'일진전기(주)': '103590.KS'},
#  {'코오롱글로벌(주)': '003070.KS'},
#  {'동국제강(주)': '001230.KS'},
#  {'삼일제약(주)': '000520.KS'},
#  {'(주)삼양패키징': '272550.KS'},
#  {'씨제이대한통운(주)': '000120.KS'},
#  {'(주)대창': '012800.KS'},
#  {'(주)까뮤이앤씨': '013700.KS'},
#  {'(주)디비아이엔씨': '012030.KS'},
#  {'(주)케이에스에스해운': '044450.KS'},
#  {'금호산업(주)': '002990.KS'},
#  {'한국철강(주)': '104700.KS'},
#  {'성신양회(주)': '004980.KS'},
#  {'에이치디씨현대산업개발(주)': '294870.KS'},
#  {'영화금속(주)': '012280.KS'},
#  {'한국항공우주산업(주)': '047810.KS'},
#  {'(주)만도': '204320.KS'},
#  {'(주)휴비스': '079980.KS'},
#  {'삼화전기(주)': '009470.KS'},
#  {'동양피스톤(주)': '092780.KS'},
#  {'(주)이스타코': '015020.KS'},
#  {'(주)한익스프레스': '014130.KS'},
#  {'코오롱인더스트리(주)': '120110.KS'},
#  {'(주)알루코': '001780.KS'},
#  {'에스지씨에너지(주)': '005090.KS'},
#  {'(주)하이스틸': '071090.KS'},
#  {'코오롱플라스틱(주)': '138490.KS'},
#  {'대원화성(주)': '024890.KS'},
#  {'신풍제지(주)': '002870.KS'},
#  {'(주)한진칼': '180640.KS'},
#  {'LG이노텍(주)': '011070.KS'},
#  {'동원시스템즈(주)': '014820.KS'},
#  {'(주)에스지글로벌': '001380.KS'},
#  {'무림피앤피(주)': '009580.KS'},
#  {'동아에스티(주)': '170900.KS'},
#  {'동일고무벨트(주)': '163560.KS'},
#  {'(주)이월드': '084680.KS'}]

# %%
df_1=[]

# %%
for stock in stocks :
  for k in stock.keys():
    df = yf.download(stock[k], start = '2009-01-01', end='2019-12-31') #기간변경
    df_1.append(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
n = 20 #이평선
sigma = 2 #시그마
base_date = '2009-01-02'

# %%
def bollinger_band(price_df, n, sigma):
    bb = price_df.copy()
    bb['center'] = price_df['Adj Close'].rolling(n).mean() #중앙 이동평균선
    bb['ub'] = bb['center'] + sigma * price_df['Adj Close'].rolling(n).std() # 상단 밴드
    bb['lb'] = bb['center'] - sigma * price_df['Adj Close'].rolling(n).std() # 하단 밴드
    return bb

# %%
def create_trade_book(sample):
    book = sample[['Adj Close']].copy()
    book['trade'] = ''
    return (book)

# %%
def tradings(sample, book):
    for i in sample.index:
        if sample.loc[i, 'Adj Close'] > sample.loc[i, 'ub']: # 상단밴드 이탈시 동작 안함
            book.loc[i, 'trade'] = ''
        elif sample.loc[i, 'lb'] > sample.loc[i, 'Adj Close']: # 하반밴드 이탈시 매수
            if book.shift(1).loc[i, 'trade'] == 'buy':    # 이미 매수상태라면
                book.loc[i, 'trade'] = 'buy'     # 매수상태 유지
            else:
                book.loc[i, 'trade'] = 'buy'    
        elif sample.loc[i, 'ub'] >= sample.loc[i, 'Adj Close'] and sample.loc[i, 'Adj Close'] >= sample.loc[i, 'lb']: # 볼린저 밴드 안에 있을 시
            if book.shift(1).loc[i, 'trade'] == 'buy':
                book.loc[i, 'trade'] = 'buy'  # 매수상태 유지
            else:
                book.loc[i, 'trade'] = '' # 동작 안함
    return (book)

# %%
def returns(book):
    # 손익 계산
    rtn = 1.0
    book['return'] = 1
    buy = 0.0
    sell = 0.0
    for i in book.index:
        if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == '':     # long 진입
            buy = book.loc[i, 'Adj Close']
#            print('진입일 : ',i, 'long 진입가격 : ', buy)
        elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy':     # long 청산
            sell = book.loc[i, 'Adj Close']
            rtn = (sell - buy) / buy + 1 # 손익 계산
            book.loc[i, 'return'] = rtn
#            print('청산일 : ',i, 'long 진입가격 : ', buy, ' |  long 청산가격 : ', \
#                  sell, ' | return:', round(rtn, 4))
    
        if book.loc[i, 'trade'] == '':     # zero position
            buy = 0.0
            sell = 0.0
    
    acc_rtn = 1.0
    for i in book.index:
        rtn = book.loc[i, 'return']
        acc_rtn = acc_rtn * rtn  # 누적 수익률 계산
        book.loc[i, 'acc return'] = acc_rtn

    print ('Accunulated return :', round(acc_rtn, 4))
    return (round(acc_rtn, 4))

# %%
C=[]

# %%
for i in range(len(stocks)):
  for comp in stocks[i].keys():
    print(comp)
  df = df_1[i]
  price_df = df.loc[:,['Adj Close']].copy()
  price_df['center'] = price_df['Adj Close'].rolling(20).mean() # 20일 이동평균선
  # +2 표준편차를 둔 상단 밴드
  price_df['ub'] = price_df['center'] + 2 * price_df['Adj Close'].rolling(20).std() 
  # -2 표준편차를 둔 하단 밴드
  price_df['lb'] = price_df['center'] - 2 * price_df['Adj Close'].rolling(20).std()
  bollinger = bollinger_band(price_df, n, sigma)
  sample = bollinger.loc[base_date:]
  book = sample[['Adj Close']].copy()
  book['trade'] = '' #거래내역 컬럼
  book = create_trade_book(sample)
  book = tradings(sample,book)
  

  for i in book.index:
    if book.loc[i, 'trade'] == 'buy' and book.shift(1).loc[i, 'trade'] == '':     # long 진입
        buy = book.loc[i, 'Adj Close']
#        print('진입일 : ',i, 'long 진입가격 : ', buy)
    elif book.loc[i, 'trade'] == '' and book.shift(1).loc[i, 'trade'] == 'buy':     # long 청산
        sell = book.loc[i, 'Adj Close']
        rtn = (sell - buy) / buy + 1 # 손익 계산
        book.loc[i, 'return'] = rtn
#        print('청산일 : ',i, 'long 진입가격 : ', buy, ' |  long 청산가격 : ', \
#              sell, ' | return:', round(rtn, 4))
            
    if book.loc[i, 'trade'] == '':     # zero position
        buy = 0.0
        sell = 0.0
  
  C.append(returns(book))
  C
   
#  print(returns(book))
# Out:
# (주)한진중공업홀딩스
# Accunulated return : 0.2405
# 금호전기(주)
# Accunulated return : 0.1664
# STX중공업(주)
# Accunulated return : 0.0092
# (주)씨아이테크
# Accunulated return : 0.3591
# 웰바이오텍(주)
# Accunulated return : 1.3031
# (주)넥스트사이언스
# Accunulated return : 2.0157
# 세하(주)
# Accunulated return : 1.6233
# (주)에이엔피
# Accunulated return : 1.4275
# 코스모화학(주)
# Accunulated return : 0.8371
# (주)엔케이
# Accunulated return : 0.5376
# 동양철관(주)
# Accunulated return : 1.928
# 서울식품공업(주)
# Accunulated return : 0.9392
# 세원이앤씨(주)
# Accunulated return : 1.7101
# 금호타이어(주)
# Accunulated return : 1.0228
# 깨끗한나라(주)
# Accunulated return : 1.2061
# (주)큐로
# Accunulated return : 1.065
# 에이치에스디엔진(주)
# Accunulated return : 0.5771
# 효성첨단소재(주)
# Accunulated return : 1.0164
# 사조동아원(주)
# Accunulated return : 1.527
# (주)코아스
# Accunulated return : 2.7141
# (주)조비
# Accunulated return : 1.1064
# (주)동방
# Accunulated return : 3.114
# 효성중공업(주)
# Accunulated return : 0.6629
# (주)세아제강
# Accunulated return : 1.1134
# 하이트진로홀딩스(주)
# Accunulated return : 0.5691
# (주)우진플라임
# Accunulated return : 1.83
# 한솔테크닉스(주)
# Accunulated return : 0.1589
# 범양건영(주)
# Accunulated return : 0.0206
# 일양약품(주)
# Accunulated return : 1.266
# 한화시스템(주)
# Accunulated return : 1.0
# (주)우진
# Accunulated return : 2.142
# 한솔제지(주)
# Accunulated return : 0.7174
# (주)크라운제과
# Accunulated return : 0.6106
# (주)지에스글로벌
# Accunulated return : 1.5773
# (주)티비에이치글로벌
# Accunulated return : 0.5567
# 효성화학(주)
# Accunulated return : 1.412
# (주)진도
# Accunulated return : 0.91
# 대우조선해양(주)
# Accunulated return : 0.3817
# 무림페이퍼(주)
# Accunulated return : 0.6789
# 효성티앤씨(주)
# Accunulated return : 1.0131
# (주)경동도시가스
# Accunulated return : 0.8575
# 신송홀딩스(주)
# Accunulated return : 0.9596
# 동원수산(주)
# Accunulated return : 7.3645
# 진흥기업(주)
# Accunulated return : 0.2624
# 아세아시멘트(주)
# Accunulated return : 1.6712
# 제일약품(주)
# Accunulated return : 1.1939
# 팬오션(주)
# Accunulated return : 0.0754
# 하이트진로(주)
# Accunulated return : 1.9102
# 삼성엔지니어링(주)
# Accunulated return : 0.4014
# 일진전기(주)
# Accunulated return : 0.7676
# 코오롱글로벌(주)
# Accunulated return : 0.5321
# 동국제강(주)
# Accunulated return : 0.6998
# 삼일제약(주)
# Accunulated return : 1.3937
# (주)삼양패키징
# Accunulated return : 0.9233
# 씨제이대한통운(주)
# Accunulated return : 1.055
# (주)대창
# Accunulated return : 4.6643
# (주)까뮤이앤씨
# Accunulated return : 1.8984
# (주)디비아이엔씨
# Accunulated return : 0.6242
# (주)케이에스에스해운
# Accunulated return : 2.6493
# 금호산업(주)
# Accunulated return : 0.2248
# 한국철강(주)
# Accunulated return : 1.151
# 성신양회(주)
# Accunulated return : 0.8381
# 에이치디씨현대산업개발(주)
# Accunulated return : 0.9327
# 영화금속(주)
# Accunulated return : 2.6442
# 한국항공우주산업(주)
# Accunulated return : 1.4578
# (주)만도
# Accunulated return : 1.8724
# (주)휴비스
# Accunulated return : 0.7349
# 삼화전기(주)
# Accunulated return : 1.7716
# 동양피스톤(주)
# Accunulated return : 1.3304
# (주)이스타코
# Accunulated return : 2.1949
# (주)한익스프레스
# Accunulated return : 0.4453
# 코오롱인더스트리(주)
# Accunulated return : 0.7587
# (주)알루코
# Accunulated return : 2.3184
# 에스지씨에너지(주)
# Accunulated return : 0.7431
# (주)하이스틸
# Accunulated return : 0.9725
# 코오롱플라스틱(주)
# Accunulated return : 1.0765
# 대원화성(주)
# Accunulated return : 2.4312
# 신풍제지(주)
# Accunulated return : 1.0022
# (주)한진칼
# Accunulated return : 1.9423
# LG이노텍(주)
# Accunulated return : 0.9856
# 동원시스템즈(주)
# Accunulated return : 1.0074
# (주)에스지글로벌
# Accunulated return : 5.0483
# 무림피앤피(주)
# Accunulated return : 1.0919
# 동아에스티(주)
# Accunulated return : 2.8453
# 동일고무벨트(주)
# Accunulated return : 0.866
# (주)이월드
# Accunulated return : 2.3753

# %%
C_1=pd.DataFrame(C)
C_1
# Out:
#          0
# 0   0.2405
# 1   0.1664
# 2   0.0092
# 3   0.3591
# 4   1.3031
# ..     ...
# 81  5.0483
# 82  1.0919
# 83  2.8453
# 84  0.8660
# 85  2.3753
#
# [86 rows x 1 columns]

# %%
C_1.rename(columns = {0 : 'Accunulated return'}, inplace = True) # 열 이름변경
C_1
# Out:
#     Accunulated return
# 0               0.2405
# 1               0.1664
# 2               0.0092
# 3               0.3591
# 4               1.3031
# ..                 ...
# 81              5.0483
# 82              1.0919
# 83              2.8453
# 84              0.8660
# 85              2.3753
#
# [86 rows x 1 columns]

# %%
C_2 = pd.concat([A['회사명'], C_1], axis=1)
C_2
# Out:
#             회사명  Accunulated return
# 0   (주)한진중공업홀딩스              0.2405
# 1       금호전기(주)              0.1664
# 2     STX중공업(주)              0.0092
# 3      (주)씨아이테크              0.3591
# 4      웰바이오텍(주)              1.3031
# ..          ...                 ...
# 81    (주)에스지글로벌              5.0483
# 82     무림피앤피(주)              1.0919
# 83     동아에스티(주)              2.8453
# 84    동일고무벨트(주)              0.8660
# 85       (주)이월드              2.3753
#
# [86 rows x 2 columns]

# %%
C_2.to_excel('/content/sample_data/Bollinger Bands for문.xlsx')
